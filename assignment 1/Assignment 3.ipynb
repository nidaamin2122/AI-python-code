# %%
                                                                #1 calculator

# %%
input1 = int (input("Enter value 1 :"))
input2 = int (input("Enter value 2 :"))
operator = input("Enter your operator")

if operator == "+":
    print(input1 + input2)
elif operator == "-":
    print(input1 - input2)
elif operator == "/":
    print(input1 / input2)
elif operator == "*":
    print(input1 * input2)
elif operator == "**":
    print(input1 ** input2)
else: 
    print("Invalid operator")
# Out:
# Enter value 1 : 4
# Enter value 2 : 2
# Enter your operator **
# 16

# %%
                                                           #2

# %%
num = ["twenty-six", "seven", 64, "eighty-two"]

for numbers in num:

    if isinstance(numbers, (int, float)):
            print (numbers, "Yes! There is a numeric value in a list.")
# Out:
# 64 Yes! There is a numeric value in a list.

# %%
                                                           #3

# %%
bio = {
        "Name" : "Ayan",
         " Age":  12,
        "Class": "Kg"
} 

bio["School"] = "Mama Baby Care School"

print(bio)
# Out:
# {'Name': 'Ayan', ' Age': 12, 'Class': 'Kg', 'School': 'Mama Baby Care School'}

# %%
                                                          #4

# %%
marks = {
          "Maths": 92,
          "English": 60,
          "Science": "Fail",
          "Urdu": 74
}

total = 0
for value in marks.values():
     if isinstance(value,(int)):
           total += value              
print (total)
# Out:
# 226

# %%
                                                         #5

# %%
a = [ 1, 2, 4, 5, 3, 2, 7, 4 ]

duplicates = []

for x in a:
    
    if a.count(x) > 1 and x not in duplicates:
        duplicates.append(x)
        
print (duplicates)
# Out:
# [2, 4]

# %%
                                                    #6

# %%
myDict ={ 
         "Name" : "Ayan",
         "Age":  12,
          "Class": "Kg"
}

key = "Age"

if key in myDict:
    print("key exists in dictionary")
else:
    print("key does not exists in dictionary")
# Out:
# key exists in dictionary
